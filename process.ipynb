# %%
import os
from pathlib import Path

wsd_path = Path("WSD_Train")

for folder in wsd_path.iterdir():
    if folder.is_dir():
        data_file = folder / "train.data.txt"  #for test data rename it to test
        gold_file = folder / "train.gold.txt"  #for test data rename it to test
        
        if data_file.exists() and gold_file.exists():
            #print(f"Folder: {folder.name}")
            
            with open(data_file, 'r') as data, open(gold_file, 'r') as gold:
                data_lines = data.readlines()
                gold_lines = gold.readlines()
                
                for data_line, gold_line in zip(data_lines, gold_lines):
                    print(data_line.strip(),"\t",gold_line.strip(),"\t",folder.name)
# Out:
# in may 2011 playboy introduced i.playboy.com , a complete , uncensored version of its near 700 issue archive , targeting the apple ipad . 	 0 	 apple
# a popular halloween - themed photo manipulation app , imut8r was named the iphone app of the week by apple october 20 , 2010 . 	 0 	 apple
# initially started as a project within apple to provide a replacement for the mac os , it was later spun off into a joint venture with ibm , for the purpose of building a competing platform to microsoft cairo and nextstep , as part of the aim alliance . 	 0 	 apple
# the changes to the dock bring its functionality also close to that of apple 's newton os button bar , as found in the messagepad 2x00 series and the likes . 	 0 	 apple
# history intel , silicon graphics , apple , and sun all had retained mode scene graph apis under development in 1996 . 	 0 	 apple
# ...

# %%
with open ("fewmapping.txt","r",encoding="utf-8") as file:
    sensedict={}
    for i in file:
        senseunit=i.split(",")[0]
        word=i.split(",")[1].split("_")[0]
        senseid=i.split(",")[2].strip("\n")
        name=str(senseunit)+" "+str(word)
        sensedict[name]=senseid

print(sensedict)
# Out:
# {'0 apple': 'apple.noun.12', '1 apple': 'apple.noun.0', '0 bank': 'bank.noun.0', '1 bank': 'bank.noun.9', '0 bat': 'bat.noun.0', '1 bat': 'bat.noun.2', '0 cell': 'cell.noun.3', '1 cell': 'cell.noun.5', '0 crane': 'crane.noun.2', '1 crane': 'crane.noun.0', '0 date': 'date.noun.0', '1 date': 'date.noun.9', '0 digit': 'digit.noun.0', '1 digit': 'digit.noun.4', '0 gum': 'gum.noun.3', '1 gum': 'gum.noun.0', '0 java': 'java.noun.1', '1 java': 'java.noun.0', '0 letter': 'letter.noun.0', '1 letter': 'letter.noun.1', '0 match': 'match.noun.0', '1 match': 'match.noun.11', '0 nail': 'nail.noun.4', '1 nail': 'nail.noun.0', '0 pitcher': 'pitcher.noun.4', '1 pitcher': 'pitcher.noun.1', '0 pupil': 'pupil.noun.0', '1 pupil': 'pupil.noun.2', '0 ring': 'ring.noun.13', '1 ring': 'ring.noun.2', '0 rock': 'rock.noun.21', '1 rock': 'rock.noun.1', '0 ruler': 'ruler.noun.1', '1 ruler': 'ruler.noun.0', '0 seal': 'seal.noun.1', '1 seal': 'seal.noun.9', '0 spring': 'spring.noun.1', '1 spring': 'spring.noun.9',
# ...

# %%
import csv

with open('WSD_train.csv', 'r',encoding='latin-1') as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        name= str(row['id'])+str(row['name'])
        print(sensedict[name])
# Out:
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.12
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# apple.noun.0
# ...
